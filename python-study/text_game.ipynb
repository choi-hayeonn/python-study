# %%
# 초기 상태 설정
print("안녕하십니까, 플레이어님. 당신의 이름은 무엇입니까?")
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
power = 10
speed = 10
mental = 10
magic = 0
divine = 0
heal = 10
inventory = []
print(f"반갑습니다, {player_name}님. 당신의 직업을 선택해 주십시오.")
player_job = input("당신의 직업을 선택하세요: 1) 귀검사🔪 2) 격투가🥊 3) 거너🔫 4) 마법사🔮 5) 프리스트🙏")

print(f"{player_name} {player_job}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌟")
print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")
print("")
if player_job == "귀검사":
    inventory.append("전설의 소드마스터의 검")
    power += 30
    speed += 10
    print("아이템 [전설의 소드마스터의 검]을 선물받으셨습니다. (전투력 +30, 민첩성 +10)")
elif player_job == "격투가":
    power += 50
    health += 20
    speed += 20
    print("강인한 전투력과 체력, 민첩성이 보강됩니다. (전투력 +30, 체력 +20, 민첩성 +20)")
elif player_job == "거너":
    inventory.append("인피니티 불렛 리볼버")
    speed += 50
    print("아이템 [인피니티 불렛 리볼버]를 선물받으셨습니다. (민첩성 +50)")
elif player_job == "마법사":
    inventory.append("어비스")
    print("아이템 [어비스]를 선물받으셨습니다. 어비스의 힘을 빌려 원소 마법을 연구해보세요.")
elif player_job == "프리스트":
    inventory.append("빛의 십자가")
    heal += 50
    print("아이템 [빛의 십자가]를 선물받으셨습니다. (치유력 +50)")
else:
    print("직업 선택을 다시 해주세요.")

print("""


""")
# 1일차 (월요일)
mon = input("시작하시겠습니까? (예/아니오)")

if mon == "예":
    print("월요일 배고픈 아침입니다. 빵을 발견했습니다.🍞")
else:
    print("제 맘대로 시작할 것 입니다~ 월요일 배고픈 아침입니다. 빵을 발견했습니다.🍞")


eat_bread = input("빵🍞을 먹겠습니까? (예/아니오): ")

if eat_bread == "예":
    health += 10
    print("빵🍞을 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다...😔 (체력 -10)")


next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("앞으로 남은 날들을 대비해, 훈련을 시작하세요.")
train_mon = input("훈련을 시작하시겠습니까? (예/아니오): ")
if train_mon == "예":
    if player_job == "귀검사":
        power += 10
        health -= 10
        speed += 10
        mental += 10
        print("""
        [전설의 소드마스터의 검]에 대한 이해도가 높아졌습니다. 
        (전투력 +10, 체력 -10, 민첩성 +10, 정신력 +10)""")
    elif player_job == "격투가":
        power += 20
        health -= 10
        speed += 10
        mental += 10
        print("""
        격투가로써의 이해도가 높아졌습니다. 
        (전투력 +20, 체력 -10, 민첩성 +10, 정신력 +10"")""")
    elif player_job == "거너":
        power += 10
        health -= 10
        speed += 10
        mental += 10
        print("""
        [인피니티 불렛 리볼버]에 대한 이해도가 높아졌습니다. 
        (전투력 +10, 체력 -10, 민첩성 +10, 정신력 +10)""")
    elif player_job == "마법사":
        power += 10
        health -= 10
        speed += 10
        magic += 50
        mental += 10
        print("""
        [어비스]에 대한 이해도가 높아짐에 따라 원소 마법을 구현하게 되었습니다. 
        (전투력 +10, 체력 -10, 민첩성 +10, 마력 +50, 정신력 +10)""")
    elif player_job == "프리스트":
        power += 10
        health -= 10
        speed += 10
        heal += 30
        mental += 30
        print("""
        [빛의 십자가]에 대한 이해도가 높아졌습니다. 
        (전투력 +10, 체력 -10, 민첩성 +10, 치유력 +30, 정신력 +30)""")
else:
    print(f"휴식 중인 {player_name}님을 누군가가 습격했습니다. {player_name}님은 아무런 대비를 못 한 채, 목숨을 잃었습니다.💀 게임오버")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")
print(f"    [아이템창]: {inventory}")
next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"월요일 밤이 찾아왔습니다. 충분한 숙면을 통해 다음날을 준비하세요.😴")


print("""


""")
# 2일차 (화요일)
wake = input("기상하시겠습니까? (예/아니오)")
if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")


print("화요일 아침이 밝았습니다.🌞 (체력 +10)")
print("배고픈 아침, 식량을 구하러 간 뒷산에 독버섯이 널려 있습니다.")
mushroom = input("독버섯을 피해가겠습니까? (예/아니오): ")
if mushroom == "예":
    print("현명한 선택입니다! (체력 변동 없음)")
else:
    if player_job == "프리스트":
        health -= 30
        print("독버섯을 먹고 배탈이 났습니다... (체력 -30)")
        healing = input("치유력을 사용하시겠습니까? (예/아니오): ")
        if healing == "예":
            heal -= 10
            health += 30
            print("치유되었습니다. (체력 +30, 치유력 -10)")
        else:
            print("아무런 변동사항이 없습니다.")
    else:
        health -= 30
        print("독버섯을 먹고 배탈이 났습니다... (체력 -30)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print("어제와 같이 훈련을 시작하세요.")
train_tue = input("훈련을 시작하시겠습니까? (예/아니오): ")
if train_tue == "예":
    if player_job == "귀검사":
        power += 50
        health -= 10
        speed += 50
        mental += 30
        print("""
        [전설의 소드마스터의 검]와 한몸이 되었습니다. 
        (전투력 +50, 체력 -10, 민첩성 +50, 정신력 +30)""")
    elif player_job == "격투가":
        power += 80
        health -= 10
        speed += 30
        mental += 30
        print("""
        마을 내 최고의 전투력을 얻었습니다. 
        (전투력 +80, 체력 -10, 민첩성 +30, 정신력 +30)""")
    elif player_job == "거너":
        power += 50
        health -= 10
        speed += 50
        mental += 30
        print("""
        [인피니티 불렛 리볼버]와 한몸이 되었습니다. 
        (전투력 +50, 체력 -10, 민첩성 +50, 정신력 +30)""")
    elif player_job == "마법사":
        power += 10
        health -= 10
        speed += 10
        magic += 80
        mental += 30
        print("""
        [어비스]의 온전한 지배자가 되었습니다. 원소 마법에 대한 이해도가 상승했습니다. 
        (전투력 +10, 체력 -10, 민첩성 +10, 마력 +80, 정신력 +30)""")
    elif player_job == "프리스트":
        power += 10
        health -= 10
        speed += 10
        heal += 50
        divine += 100
        mental += 50
        print("""
        [빛의 십자가]의 온전한 주인이 되었습니다. 신성력을 자유자재로 사용해보세요. 
        (전투력 +10, 체력 -10, 민첩성 +10, 치유력 +50, 신성력 +100, 정신력 +50)""")
else:
    health += 30
    mental -= 10
    print(f"낮잠을 자고 일어난 {player_name}님의 몸이 한결 가벼워졌습니다. (체력 +30, 정신력 -10)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")


next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"열심히 훈련 후, 허기진 {player_name}님에게 마을 이장이 저녁 식사를 초대했습니다.")
dinner_tue = input("식사 초대를 수락하시겠습니까? (예/아니오): ")
if dinner_tue == "예":
    health += 30
    heal += 30
    print("""
    이장의 가족들과 함께 만족스러운 식사를 마쳤습니다. 
    마을 이장의 정체는 은퇴한 🔯백마법사🕎였습니다. 
    그의 마법의 포션이 들어간 요리를 먹은 후 체력 뿐 아니라 치유력까지 얻게되었습니다. 
    (체력 +30, 치유력 +30)""")
else:
    health -= 50
    mental -= 10
    print("식량을 찾지 못한 당신은 굶주린 채 집으로 돌아왔습니다. (체력 -50, 정신력 -10)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")
print("")
print("화요일 밤이 찾아왔습니다. 충분한 숙면을 통해 다음날을 준비하세요.😴")

print("""


""")

# 3일차 (수요일)
wake = input("기상하시겠습니까? (예/아니오)")

if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")

print("수요일 아침이 밝았습니다. 오늘의 날씨는 흐립니다.🌂")
health += 10
print("배고픈 아침, 식량을 구하기 위해 집 밖을 나섰습니다.")

door = input("문을 여시려면 '예'라고 작성해주세요.")

if door == "예":
    print("끼이익")

dinner_tue = input("어제 저녁 식사를 이장님의 식구들과 함께 했나요?")

if dinner_tue == "예":
    health += 10
    heal += 10
    print("""
    어젯밤 당신을 좋게 본 이장과 마을사람들이 푸짐한 아침식사를 당신의 문 밖에 두고 갔습니다. 
    맛있게 먹으세요~🍳 (체력 +10, 치유력 +10)""")
else:
    health -= 10
    mental -= 10
    print("식량을 찾지 못한 당신은 굶주린 채 다시 집으로 돌아왔습니다. (체력 -30, 정신력 -10)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")
print("")
print("오늘도 훈련을 시작해보세요.")
train_wed = input("훈련을 시작하시겠습니까? (예/아니오): ")
if train_wed == "예":
    if player_job == "귀검사":
        inventory.append("뇌신의 스톰브레이커")
        power += 100
        health -= 10
        speed += 100
        mental += 50
        print("""
        단숨에 노블레스 반열에 올랐습니다. 아이템 [뇌신의 스톰브레이커]를 선물받았습니다. 
        (전투력 +100, 체력 -10, 민첩성 +100, 정신력 +50)""")
    elif player_job == "격투가":
        power += 150
        health -= 10
        speed += 100
        mental += 50
        print("""
        단숨에 무극의 반열에 올랐습니다. 2차 각성 후 패황의 자리에 도전하세요. 
        (전투력 +150, 체력 -10, 민첩성 +100, 정신력 +50)""")
    elif player_job == "거너":
        inventory.append("마법의 그랜드 캐넌")
        power += 100
        health -= 10
        speed += 100
        mental += 50
        print("""
        [인피니티 불렛 리볼버]에 대한 높은 이해도로 [마법의 그랜드 캐넌]을 선물받았습니다. 
        다양한 화기를 활용한 공격이 특기인 거너, 스핏 파이어에 도전해보세요. 
        (전투력 +100, 체력 -10, 민첩성 +100, 정신력 +50)""")
    elif player_job == "마법사":
        power += 100
        health -= 10
        speed += 60
        magic += 150
        mental += 50
        print("""
        단숨에 엘레멘탈마스터의 반열에 올랐습니다. 대마법사에 도전해보세요. 
        (전투력 +100, 체력 -10, 민첩성 +60, 마력 +150, 정신력 +50)""")
    elif player_job == "프리스트":
        power += 50
        health -= 10
        speed += 50
        heal += 100
        divine += 200
        mental += 100
        print("""
        [빛의 십자가]에 신성한 숨결이 깃들어 단숨에 크루세이터의 반열에 올랐습니다. 
        (전투력 +50, 체력 -10, 민첩성 +50, 치유력 +100, 신성력 +200, 정신력 +80)""")
else:
    health += 30
    mental -= 30
    print(f"낮잠을 자고 일어난 {player_name}님의 몸이 한결 가벼워졌습니다. (체력 +30, 정신력 -30)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

print(f"    [아이템창]: {inventory}")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")


if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"열심히 훈련 후, 허기진 {player_name}님은 식량을 찾았습니다.")
dinner_wed = input("마을 이장 식구를 저녁 식사에 초대하시겠습니까? (예/아니오): ")
if dinner_wed == "예":
    health += 30
    mental += 50
    print("""
    마을 이장 식구 분들에게 저녁 식사를 대접하셨군요!🥘


    이장의 가족들과 함께 만족스러운 식사를 마쳤습니다. 
    마을 이장이 감사의 인사로 정신력 상승 포션을 선물했습니다.🎁 (체력 +30, 정신력 +50)""")
else:
    health += 50
    print("홀로 많은 양의 식사를 배불리 마쳤습니다. (체력 +50)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")
        
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")
print("")
print(f"수요일 밤이 찾아왔습니다. 충분한 숙면을 통해 다음날을 준비하세요.😴")

print("""


""")

# 4일차 (목요일)
wake = input("기상하시겠습니까? (예/아니오)")
if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")

print("목요일 아침이 밝았습니다. 밖에는 폭풍우가 내리고 있습니다.🌀")
health += 10

print("배고픈 아침, 식량을 구하기 위해 집 밖을 나섰습니다.")
dinner_wed = input("전날 밤 이장의 식구들과 함께 저녁식사를 했나요?")
if dinner_wed == "예":
    health += 10
    heal += 10
    print("이장이 푸짐한 아침식사를 당신의 문 밖에 두고 갔습니다. 맛있게 먹으세요~ (체력 +10, 치유력 +10)")
else:
    health -= 10
    mental -= 10
    print("거센 폭풍우에 식량을 찾지 못한 당신은 굶주린 채 다시 집으로 돌아왔습니다. (체력 -30, 정신력 -10)")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"""
거센 비바람에도 훈련을 위해 집 밖을 나선 {player_name}님, 
심상치 않은 기운에 고개를 돌리니 
🧟‍♂️🧝‍♀️적의 무리🧛‍♀️🧙‍♂️가 마을을 향해 오는 것을 목격하였습니다.""")
print("""
🧟‍♂️🧝‍♀️적의 무리🧛‍♀️🧙‍♂️는 한눈에 봐도 제압할 수 없을 정도로 강하고, 
그 수가 너무 많아 헤아릴 수 없을 정도입니다.""")

fight = input("죽음을 각오하고 전투를 준비하시겠습니까? (전투준비/도망): ")
if fight == "전투준비":
    print(f"""
    적들을 모두 물리치기엔 {player_name}님은 능력이 부족합니다. 
    안타깝게도, {player_name}님은 치열한 전투 속에서 작렬히 전사하셨습니다. 
    살아남은 마을 사람들은 {player_name}님의 희생을 절대 잊지 않을 것 입니다. 게임오버🌠""")
else:
    health -= 10
    mental -= 50
    print(f"""
    {player_name}님은 마을을 저버린 채 도망쳤습니다. 
    마을 사람들의 비명을 들으며 {player_name}님의 정신력이 몹시 흔들립니다. 
    (체력 -10, 정신력 -50)""")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"목요일 밤이 찾아왔습니다. 안전한 곳을 찾아 다음날을 위해 숙면을 취하세요.😴")

print("""


""")
# 5일차 (금요일)
wake = input("기상하시겠습니까? (예/아니오)")
if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")

print("[금요일] 아침이 밝았습니다. 오늘의 날씨는 화창합니다.🍀")

print(f"""
눈을 떠보니 {player_name}님이 잠든 곳이 🌲정령의 숲🌄이라는 사실을 알게되었습니다. 
🧚‍♀️숲의 정령들이 외부인인 {player_name}님을 보자 적대감을 표합니다.""")
forest = input("🧚‍♀️숲의 정령들과 대화를 나누겠습니까? (대화/도망): ")
if forest == "대화":
    health += 10
    mental += 10
    print(f"""
    🧚‍♀️숲의 정령들이 {player_name}님을 마음에 들어합니다.💚
    숲의 정령들이 아침식사🥗를 대접합니다. (체력 +10, 정신력 +10)""")
else:
    health -= 30
    mental -= 50
    power -= 50
    print(f"""
    {player_name}님은 🧚‍♀️숲의 정령들을 공격하며 도망치려 했습니다. 
    하지만, 🌲정령의 숲🌄에서 {player_name}님은 🧚‍♀️숲의 정령들을 이길 수 없습니다. 
    (체력 -30, 정신력 -50, 공격력 -50)""")
    apology = input("숲의 정령들에게 사과🍎하시겠습니까? (예/아니오): ")
    if apology == "예":
        health += 10
        mental += 10
        print(f"""
        🧚‍♀️숲의 정령들이 {player_name}님의 사과🍎를 받아들입니다.
        숲의 정령들이 아침식사를 대접합니다.🥗 (체력 +10, 정신력 +10)""")
    else:
        print(f"""
        🧚‍♀️숲의 정령들이 {player_name}님을 무자비하게 공격합니다. 
        🧚‍♀️숲의 정령들의 공격에 {player_name}님은 속수무책으로 목숨을 잃습니다.👻 게임오버""")


print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

print("")
next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print(f"🧚‍♀️숲의 정령들의 도움을 받아 오늘도 훈련을 시작해보세요.")
train_fri = input("훈련을 시작하시겠습니까? (예/아니오): ")
if train_fri == "예":
    if player_job == "귀검사":
        inventory.append("신성한 숲의 검")
        power += 200
        health += 10
        speed += 200
        mental += 100
        print("""
        🌲정령의 숲🌄 숨결의 도움을 받아 단숨에 마제스티의 반열에 올랐습니다. 
        숲의 대장장이 정령에게 아이템 [신성한 숲의 검]을 선물받았습니다.🎁 
        (전투력 +200, 체력 +10, 민첩성 +200, 정신력 +100)""")
    elif player_job == "격투가":
        inventory.append("전설의 건틀릿")
        power += 300
        health += 10
        speed += 200
        mental += 100
        print("""
        🌲정령의 숲🌄 숨결의 도움을 받아 단숨에 패황의 반열에 올랐습니다. 
        숲의 대장장이 정령에게 아이템 [전설의 건틀릿]을 선물받았습니다.🎁 
        (전투력 +300, 체력 +10, 민첩성 +200, 정신력 +100)""")
    elif player_job == "거너":
        inventory.append("전설의 보우건")
        power += 200
        health += 10
        speed += 200
        mental += 100
        print("""
        🌲정령의 숲🌄 숨결의 도움을 받아 스핏 파이어가 되었습니다.
        숲의 대장장이 정령에게 아이템 [전설의 보우건]을 선물받았습니다.🎁 
        (전투력 +200, 체력 +10, 민첩성 +200, 정신력 +100)""")
    elif player_job == "마법사":
        inventory.append("정령의 마법술")
        power += 200
        health += 10
        speed += 100
        magic += 300
        mental += 100
        print("""
        🌲정령의 숲🌄 숨결의 도움을 받아 단숨에 대마법사의 반열에 올랐습니다. 
        숲의 정령에게 [정령의 마법술]을 전수받았습니다.🏆 
        (전투력 +200, 체력 +10, 민첩성 +100, 마력 +300, 정신력 +100)""")
    elif player_job == "프리스트":
        inventory.append("신성력 강화술")
        power += 100
        health += 10
        speed += 80
        heal += 200
        divine += 300
        mental += 200
        print("""
        🌲정령의 숲🌄 숨결의 도움을 받아 단숨에 게인트의 반열에 올랐습니다. 
        숲의 정령에게 [신성력 강화술]을 전수받았습니다.🏆 
        (전투력 +100, 체력 +10, 민첩성 +80, 치유력 +200, 신성력 +300, 정신력 +200)""")
else:
    health += 30
    mental -= 30
    print(f"""
    낮잠을 자고 일어난 {player_name}님의 몸이 한결 가벼워졌습니다. 
    (체력 +30, 정신력 -30)""")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

print(f"    [아이템창]: {inventory}")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print("""
금요일 밤이 찾아왔습니다. 
🧚‍♀️숲의 정령들과의 맛있는 저녁 식사 후, 그들이 마련해준 보금자리에서 숙면을 취하세요😴""")

print("""


""")
# 6일차 (토요일)
wake = input("기상하시겠습니까? (예/아니오)")
if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")

print("토요일 아침이 밝았습니다. 오늘의 날씨도 역시 화창합니다.🍀")
print(f"""
🧚‍♀️숲의 정령들이 {player_name}님에게 아침식사를 대접합니다. 

아침식사를 하며, 🧚‍♀️숲의 정령들이 당신이 있던 마을에 대한 정보를 알려줍니다. 
마을 사람들 몇은 살아있으며, 적들에게 수탈을 당하고 착취당하고 있다고 합니다.""")

health += 30
help = input("🧚‍♀️숲의 정령들에게 마을을 되찾는데 함께 해주겠냐고 도움을 청하시겠습니까? (예/아니오): ")
if help == "예":
    mental += 50
    print(f"""
    🧚‍♀️숲의 정령들이 회의 끝에 {player_name}님의 요청을 수락합니다.
    🧚‍♀️숲의 정령들과 내일 있을 전투를 준비하세요. (정신력 +50)""")
else:
    mental -= 10
    print(f"""
    🧚‍♀️숲의 정령들이 {player_name}님에게 정령의 숲에서 자신들과 함께 하자고 제안합니다.""")
    propose = input("🧚‍♀️숲의 정령들의 제안을 수락하시겠습니까? (예/아니오): ")
    if propose == "예":
        mental -= 50
        print(f"""
        🧚‍♀️숲의 정령들이 마을을 버리는 {player_name}님의 무책임한 태도에 크게 실망합니다.
        🧚‍♀️숲의 정령들이 🌲정령의 숲🌄을 당장 떠나라고 합니다. 
        {player_name}님은 농담이라며 거짓말을 하고, 
        어쩔 수 없이 🧚‍♀️숲의 정령들에게 마을을 되찾는데 함께 해주겠냐고 도움을 청합니다.
        🧚‍♀️숲의 정령들의 수락에 {player_name}님은 내일 있을 전투를 준비하게 되었습니다.(정신력 -50)""")
    else:
        mental -= 30
        print(f"""
        🧚‍♀️숲의 정령들이 {player_name}님에게 먼저 마을을 되찾는데 도움이 되어주겠다고 제안합니다. 
        {player_name}님은 어쩔 수 없이 🧚‍♀️숲의 정령들과 내일 있을 전투를 준비하게 되었습니다.(정신력 -30)""")

print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 게임 오버")
else:
    print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")    
print(f"""
🧚‍♀️숲의 정령들과 열심히 전투 준비를 하다보니 토요일 밤이 찾아왔습니다. 
숲의 정령들과의 맛있는 저녁 식사 후, 
내일 전투를 대비하여 깊은 숙면을 취하세요😴 """)

print("""


""")
# 7일차 (일요일)
wake = input("기상하시겠습니까? (예/아니오)")
if wake == "예":
    print("좋은아침입니다.😄")
    health += 10
else:
    print("일어나세요.😑")

print("""
결전의 일요일 아침이 밝았습니다. 
오늘은 태양이 강하게 내리쬐고 있습니다.🌞 
승리가 당신과 함께하길🍀💪""")
print("")
print(f"""
🧚‍♀️숲의 정령들이 {player_name}님에게 아침식사를 대접합니다. 
아침식사를 하며, 전날 연습한 전투 시뮬레이션을 상기합니다.""")
health += 50
print("")

print("🧚‍♀️숲의 정령들과 마을로 돌아갔습니다. 적들에게서 마을을 구하세요.")

combat = input("전투를 시작하시겠습니까? (예/아니오): ")
if combat == "예":
    if player_job == "귀검사":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "격투가":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "거너":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "마법사":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "프리스트":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
else:
    mental -= 30
    print(f"""
    🧚‍♀️숲의 정령들이 {player_name} {player_job}님에게 크게 실망하였습니다. 
    🧚‍♀️숲의 정령들에게 떠밀려 전투에 참가하게 되었습니다. (정신력 -30)""")
    if player_job == "귀검사":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "격투가":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "거너":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "마법사":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
    elif player_job == "프리스트":
        print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

        print(f"    [아이템창]: {inventory}")

        print(f"{player_name} {player_job}님 마을을 구하기 위한 적과의 전투를 시작합니다.")
print("""


""")        
print("🏹")
print("🔪")
print("💣")
print("🔫")
print("🪓")
print("🏴‍☠️")
print("🎇")
print("🎩")
print("🔮")
print("🩸")
print("""


""")
glory = input("전투가 모두 끝났습니다. 결과를 보시겠습니까? (예/아니오)")
if glory == "예":
    print(f"{player_name} {player_job}님과 🧚‍♀️숲의 정령들이 적들에 맞서 싸워 마을을 지켜냈습니다.")
    power += 300
    health -= 100
    speed += 80
    heal -= 50
    mental += 500
else:
    print(f"{player_name} {player_job}님과 🧚‍♀️숲의 정령들이 적들에 맞서 싸워 마을을 지켜냈습니다.")
    power += 300
    health -= 100
    speed += 80
    heal -= 50
    mental += 100
print("""

""")
print(f"""
        [상태창]
        현재 체력:  {health}
        현재 정신력: {mental}
        현재 전투력: {power}
        현재 민첩성: {speed}
        현재 정신력: {mental}
        현재 치유력: {heal}
        현재 신성력: {divine}""")

if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 당신은 마을을 지켜낸 후 작렬히 전사하였습니다. 모두가 당신을 기억할 것입니다.✝ 게임 오버")
else:
    print("")

if mental <= 0:
    print("😱 정신력이 바닥나 폭주하였습니다. 당신은 마을을 지켜낸 후 작렬히 전사하였습니다. 모두가 당신을 기억할 것입니다.✝ 게임 오버")
else:
    print("")

if mental <= 0:
    print(f"😨 치유력이 바닥나 위태롭습니다. 당신이 구한 마을이장이 서둘러 당신에게 치유 포션을 먹여주어, {player_name}님은 극적으로 살아났습니다.")
else:
    print("")

print("")

next = input("다음으로 넘어가시겠습니까? (예/아니오)")
if next == "예":
    print("😄")
else:
    print("😑")

print("")
print(f"""{player_name} {player_job}님은 마을을 지켜낸 업적으로 영웅🤴으로 추대되었습니다. 
오늘은 던전에서의 마지막 날입니다. 영웅으로써 마을 잔치에서 충분히 즐기시길 바랍니다.🍸""")
print("""


""")

print("🌼")
print("🍖")
print("🍰")
print("🍷")
print("🍹")
print("🎂")
print("🍩")
print("🍴")
print("🍉")
print("🌻")

print("""


""")

print(f"이별의 시간이 다가왔습니다")
bye = input("현실세계로 돌아가시겠습니까? 계속 던전에서 머무르시겠습니까? (현실/던전): ")
if bye == "현실":
    print(f"마을의 영웅 {player_name} {player_job}님 던전에서의 일주일을 마칩니다.🖐")
else:
    print(f"새로운 이벤트가 발생합니다!🎇")
# Out:
# 안녕하십니까, 플레이어님. 당신의 이름은 무엇입니까?
# 반갑습니다, 철수님. 당신의 직업을 선택해 주십시오.
# 철수 프리스트님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌟
#
#         [상태창]
#         현재 체력:  100
#         현재 정신력: 10
#         현재 전투력: 10
#         현재 민첩성: 10
#         현재 정신력: 10
#         현재 치유력: 10
#         현재 신성력: 0
#
# 아이템 [빛의 십자가]를 선물받으셨습니다. (치유력 +50)
#
#
#
#
# 월요일 배고픈 아침입니다. 빵을 발견했습니다.🍞
# 빵🍞을 먹고 힘이 납니다! (체력 +10)
# 😄
# 앞으로 남은 날들을 대비해, 훈련을 시작하세요.
#
#         [빛의 십자가]에 대한 이해도가 높아졌습니다.
#         (전투력 +10, 체력 -10, 민첩성 +10, 치유력 +30, 정신력 +30)
#
#         [상태창]
#         현재 체력:  100
#         현재 정신력: 40
#         현재 전투력: 20
#         현재 민첩성: 20
#         현재 정신력: 40
#         현재 치유력: 90
#         현재 신성력: 0
#     [아이템창]: ['빛의 십자가']
# 😄
#
# 월요일 밤이 찾아왔습니다. 충분한 숙면을 통해 다음날을 준비하세요.😴
#
#
#
#
# 좋은아침입니다.😄
# 화요일 아침이 밝았습니다.🌞 (체력 +10)
# 배고픈 아침, 식량을 구하러 간 뒷산에 독버섯이 널려 있습니다.
# 독버섯을 먹고 배탈이 났습니다... (체력 -30)
# 치유되었습니다. (체력 +30, 치유력 -10)
#
#         [상태창]
#         현재 체력:  110
#         현재 정신력: 40
#         현재 전투력: 20
#         현재 민첩성: 20
#         현재 정신력: 40
# ...
